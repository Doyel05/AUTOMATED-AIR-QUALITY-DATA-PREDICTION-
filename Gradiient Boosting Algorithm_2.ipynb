# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv",nrows=300)

# %%
df
# Out:
#       No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO  O3  TEMP  \
# 0      1  2013      3    1     0      4   4.0   4.0   7.0  300.0  77  -0.7
# 1      2  2013      3    1     1      8   8.0   4.0   7.0  300.0  77  -1.1
# 2      3  2013      3    1     2      7   7.0   5.0  10.0  300.0  73  -1.1
# 3      4  2013      3    1     3      6   6.0  11.0  11.0  300.0  72  -1.4
# 4      5  2013      3    1     4      3   3.0  12.0  12.0  300.0  72  -2.0
# ..   ...   ...    ...  ...   ...    ...   ...   ...   ...    ...  ..   ...
# 295  296  2013      3   13     7      3   8.0  21.0  40.0  600.0  69   3.7
# 296  297  2013      3   13     8      8  18.0  35.0  62.0  700.0  69   4.8
# 297  298  2013      3   13     9     20  24.0  27.0  43.0  600.0  69   5.5
# 298  299  2013      3   13    10     16  25.0  22.0  32.0  500.0  69   6.4
# 299  300  2013      3   13    11     14   6.0  14.0  26.0  400.0  69   6.6
#
#        PRES  DEWP  RAIN   wd  WSPM       station
# 0    1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1    1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2    1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3    1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4    1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# ..      ...   ...   ...  ...   ...           ...
# 295  1023.3 -10.0   0.0  NNE   2.9  Aotizhongxin
# 296  1024.6 -13.6   0.0  NNE   3.3  Aotizhongxin
# 297  1025.2 -10.7   0.0  ENE   3.9  Aotizhongxin
# 298  1025.2 -11.3   0.0  ENE   2.6  Aotizhongxin
# 299  1024.4 -12.6   0.0   NE   3.6  Aotizhongxin
#
# [300 rows x 18 columns]

# %%
df_new=df.drop(['No','wd','station'], axis=1)

# %%
df_new.isnull().sum()
# Out:
# year     0
# month    0
# day      0
# hour     0
# PM2.5    0
# PM10     1
# SO2      2
# NO2      2
# CO       5
# O3       0
# TEMP     0
# PRES     0
# DEWP     0
# RAIN     0
# WSPM     0
# dtype: int64

# %%
test_data = df_new[df_new['CO'].isnull()]

# %%
test_data
# Out:
#      year  month  day  hour  PM2.5   PM10       SO2       NO2  CO  O3  TEMP  \
# 75   2013      3    4     3     12   34.0    6.0000   12.0000 NaN  77   7.2
# 124  2013      3    6     4    192  203.0   83.6808  140.4252 NaN  22   3.9
# 171  2013      3    8     3    324  373.0   71.0000  154.0000 NaN  84   1.8
# 178  2013      3    8    10    326  844.0  125.9496  179.2269 NaN  84  19.1
# 267  2013      3   12     3    117  127.0   73.0000   81.0000 NaN  47   6.4
#
#        PRES  DEWP  RAIN  WSPM
# 75   1016.9 -11.6   0.0   2.8
# 124  1007.3  -6.1   0.0   1.4
# 171   997.9  -1.8   0.0   0.0
# 178  1000.9  -0.4   0.0   1.9
# 267  1005.8  -1.0   0.1   2.2

# %%
df_new.dropna(inplace = True)

# %%
X_train = df_new.drop(['CO'] , axis = 1)
y_train = df_new['CO']

# %%
X_train
# Out:
#      year  month  day  hour  PM2.5  PM10   SO2   NO2  O3  TEMP    PRES  DEWP  \
# 0    2013      3    1     0      4   4.0   4.0   7.0  77  -0.7  1023.0 -18.8
# 1    2013      3    1     1      8   8.0   4.0   7.0  77  -1.1  1023.2 -18.2
# 2    2013      3    1     2      7   7.0   5.0  10.0  73  -1.1  1023.5 -18.2
# 3    2013      3    1     3      6   6.0  11.0  11.0  72  -1.4  1024.5 -19.4
# 4    2013      3    1     4      3   3.0  12.0  12.0  72  -2.0  1025.2 -19.5
# ..    ...    ...  ...   ...    ...   ...   ...   ...  ..   ...     ...   ...
# 295  2013      3   13     7      3   8.0  21.0  40.0  69   3.7  1023.3 -10.0
# 296  2013      3   13     8      8  18.0  35.0  62.0  69   4.8  1024.6 -13.6
# 297  2013      3   13     9     20  24.0  27.0  43.0  69   5.5  1025.2 -10.7
# 298  2013      3   13    10     16  25.0  22.0  32.0  69   6.4  1025.2 -11.3
# 299  2013      3   13    11     14   6.0  14.0  26.0  69   6.6  1024.4 -12.6
#
#      RAIN  WSPM
# 0     0.0   4.4
# 1     0.0   4.7
# 2     0.0   5.6
# 3     0.0   3.1
# 4     0.0   2.0
# ..    ...   ...
# 295   0.0   2.9
# 296   0.0   3.3
# 297   0.0   3.9
# 298   0.0   2.6
# 299   0.0   3.6
#
# [290 rows x 14 columns]

# %%
y_train
# Out:
# 0      300.0
# 1      300.0
# 2      300.0
# 3      300.0
# 4      300.0
#        ...
# 295    600.0
# 296    700.0
# 297    600.0
# 298    500.0
# 299    400.0
# Name: CO, Length: 290, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
LR = {'learning_rate':[0.15,0.1,0.10,0.05], 'n_estimators':[100,150,200,250,300], 'max_depth':[1,3,5,7,9]}
tuning = GridSearchCV(estimator = GradientBoostingRegressor(),param_grid = LR,scoring='r2')
tuning.fit(X_train,y_train)
tuning.best_params_, tuning.best_score_
# Out:
# ({'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 300},
#  0.6463785123959109)

# %%
X_test = test_data[['year','month','day','hour','PM2.5','PM10','SO2','NO2','O3','TEMP','PRES','DEWP','RAIN','WSPM']]

# %%
gradientregressor = GradientBoostingRegressor(max_depth=3,n_estimators=300,learning_rate=0.05)

# %%
model = gradientregressor.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
test_data['y_pred'] = y_pred

# %%
test_data
# Out:
#      year  month  day  hour  PM2.5   PM10       SO2       NO2  CO  O3  TEMP  \
# 75   2013      3    4     3     12   34.0    6.0000   12.0000 NaN  77   7.2
# 124  2013      3    6     4    192  203.0   83.6808  140.4252 NaN  22   3.9
# 171  2013      3    8     3    324  373.0   71.0000  154.0000 NaN  84   1.8
# 178  2013      3    8    10    326  844.0  125.9496  179.2269 NaN  84  19.1
# 267  2013      3   12     3    117  127.0   73.0000   81.0000 NaN  47   6.4
#
#        PRES  DEWP  RAIN  WSPM       y_pred
# 75   1016.9 -11.6   0.0   2.8   336.389236
# 124  1007.3  -6.1   0.0   1.4  2530.664083
# 171   997.9  -1.8   0.0   0.0  3857.188561
# 178  1000.9  -0.4   0.0   1.9  4093.566637
# 267  1005.8  -1.0   0.1   2.2  1627.893229
